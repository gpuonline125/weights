# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/UBS-Auto_Server_Audit /mask-rcnn-tf2/'
# Out:
# /content/drive/.shortcut-targets-by-id/1xuo4FVROJBpOYQfz9QcDshp5kPAvpxB1/UBS-Auto_Server_Audit /mask-rcnn-tf2

# %%
cd Mask_RCNN
# Out:
# /content/drive/.shortcut-targets-by-id/1xuo4FVROJBpOYQfz9QcDshp5kPAvpxB1/UBS-Auto_Server_Audit /mask-rcnn-tf2/Mask_RCNN

# %%
# !zip Mask_RCNN.zip *
# Out:
#   adding: mask-rcnn-tf2.ipynb (deflated 41%)
#   adding: Mask R-CNN - Train on Shapes Dataset.ipynb (deflated 85%)
#   adding: mrcnn/ (stored 0%)
#   adding: weights/ (stored 0%)

# %%
# !tar -chvzf maskkeras.tar.gz *
# Out:
# mask-rcnn-tf2.ipynb
# Mask R-CNN - Train on Shapes Dataset.ipynb
# mrcnn/
# mrcnn/__init__.py
# mrcnn/config.py
# mrcnn/parallel_model.py
# mrcnn/utils.py
# mrcnn/visualize.py
# mrcnn/__pycache__/
# mrcnn/__pycache__/__init__.cpython-37.pyc
# mrcnn/__pycache__/config.cpython-37.pyc
# mrcnn/__pycache__/utils.cpython-37.pyc
# mrcnn/__pycache__/visualize.cpython-37.pyc
# mrcnn/__pycache__/model.cpython-37.pyc
# mrcnn/model.py
# weights/
# weights/mask_rcnn_coco.h5

# %%
# !tar -xvzf maskkeras.tar.gz
# Out:
# tar (child): maskkeras.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1xuo4FVROJBpOYQfz9QcDshp5kPAvpxB1/UBS-Auto_Server_Audit /mask-rcnn-tf2/Mask_RCNN'
